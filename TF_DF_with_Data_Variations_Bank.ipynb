# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikmswamy/TF_Intro_Notebooks/blob/master/TF_DF_with_Data_Variations_Bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installs

# %%
# !pip install -U augly
# !sudo apt-get install python3-magic
# !pip install tensorflow_decision_forests
# !pip install wurlitzer
# Out:
# Collecting tensorflow_decision_forests
#   Downloading tensorflow_decision_forests-0.1.9-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 4.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorflow_decision_forests) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from tensorflow_decision_forests) (1.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorflow_decision_forests) (1.15.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow_decision_forests) (0.12.0)
# Requirement already satisfied: tensorflow~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow_decision_forests) (2.6.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from tensorflow_decision_forests) (0.37.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (1.6.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (1.1.2)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (1.1.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (0.4.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (2.6.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (1.12)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (1.39.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (3.7.4.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (3.1.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (2.6.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (1.12.1)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (5.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.6->tensorflow_decision_forests) (3.17.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow~=2.6->tensorflow_decision_forests) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (0.4.5)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (1.34.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (4.6.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow~=2.6->tensorflow_decision_forests) (3.5.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->tensorflow_decision_forests) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->tensorflow_decision_forests) (2.8.2)
# Installing collected packages: tensorflow-decision-forests
# Successfully installed tensorflow-decision-forests-0.1.9
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.2-py3-none-any.whl (7.3 kB)
# Installing collected packages: wurlitzer
# Successfully installed wurlitzer-3.0.2

# %% [markdown]
# ## Imports

# %%
from time import time

import tensorflow_decision_forests as tfdf
import pandas as pd
import tensorflow as tf
try:
  from wurlitzer import sys_pipes
except:
  from colabtools.googlelog import CaptureLog as sys_pipes

from IPython.core.magic import register_line_magic
from IPython.display import Javascript
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Download and Check

# %%
! wget -O bank.zip "https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip" 

! unzip bank.zip
# Out:
# --2021-08-31 17:06:07--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444572 (434K) [application/x-httpd-php]
# Saving to: ‘bank.zip’
#
# bank.zip            100%[===================>] 434.15K  1.32MB/s    in 0.3s
#
# 2021-08-31 17:06:08 (1.32 MB/s) - ‘bank.zip’ saved [444572/444572]
#
# Archive:  bank.zip
#    creating: bank-additional/
#   inflating: bank-additional/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/bank-additional/
#   inflating: __MACOSX/bank-additional/._.DS_Store
#   inflating: bank-additional/.Rhistory
#   inflating: bank-additional/bank-additional-full.csv
#   inflating: bank-additional/bank-additional-names.txt
#   inflating: bank-additional/bank-additional.csv
#   inflating: __MACOSX/._bank-additional

# %%
# Load a dataset into a Pandas Dataframe.
dataset_df = pd.read_csv("./bank-additional/bank-additional-full.csv", delimiter=';')

# Display the first 3 examples.
dataset_df.head(3)
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
#
# [3 rows x 21 columns]

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
# Name of the label column.
label = "y"

classes = dataset_df[label].unique().tolist()
print(f"Label classes: {classes}")

dataset_df[label] = dataset_df[label].map(classes.index)
# Out:
# Label classes: ['no', 'yes']

# %%
print(f"Number of records: {len(dataset_df)}")
# Out:
# Number of records: 41188

# %% [markdown]
# ## Helper Methods

# %%
# Split the dataset into a training and a testing dataset.
# Test split remains a constant 
def split_dataset(dataset, num_train=10000):
  """Splits a panda dataframe in two."""
  dataset = dataset.sample(frac=1.0, random_state=1729)
  
  test_dataset = dataset[35000:]
  train_dataset = dataset[:num_train]
  
  return train_dataset, test_dataset

# %%
def train_rf_model_with_dataframes(train_df, test_df, label):
    train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label=label)
    test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, label=label)

    # Specify the model.
    model_1 = tfdf.keras.RandomForestModel(num_trees=30)

    # Optionally, add evaluation metrics.
    model_1.compile(metrics=["accuracy"])

    t1 = time()
    # Train the model.
    with sys_pipes():
        model_1.fit(x=train_ds)

    evaluation = model_1.evaluate(test_ds)

    # print(f"Loss: {evaluation[0]}")
    print(f"Accuracy: {evaluation[1]} in {time() - t1} secs")
    return evaluation[1], time() - t1

# %%
def train_gbdt_model_with_dataframes(train_df, test_df, label):
    train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label=label)
    test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, label=label)

    # Specify the model.
    model_1 = tfdf.keras.GradientBoostedTreesModel(num_trees=30)

    # Optionally, add evaluation metrics.
    model_1.compile(metrics=["accuracy"])

    t1 = time()
    # Train the model.
    with sys_pipes():
        model_1.fit(x=train_ds)

    evaluation = model_1.evaluate(test_ds)

    # print(f"Loss: {evaluation[0]}")
    print(f"Accuracy: {evaluation[1]} in {time() - t1} secs")
    return evaluation[1], time() - t1

# %%
def train_cart_model_with_dataframes(train_df, test_df, label):
    train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label=label)
    test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, label=label)

    # Specify the model.
    model_1 = tfdf.keras.CartModel()

    # Optionally, add evaluation metrics.
    model_1.compile(metrics=["accuracy"])

    t1 = time()
    # Train the model.
    with sys_pipes():
        model_1.fit(x=train_ds)

    evaluation = model_1.evaluate(test_ds)

    # print(f"Loss: {evaluation[0]}")
    print(f"Accuracy: {evaluation[1]} in {time() - t1} secs")
    return evaluation[1], time() - t1

# %% [markdown]
# ## Train with Different Records

# %%
def train_and_evaluate_on_data(num_train, results_rf, results_gb, results_cm):
    train_ds_pd, test_ds_pd = split_dataset(dataset_df, num_train)
    print(f"{len(train_ds_pd)} examples in training, {len(test_ds_pd)} examples for testing.")

    accuracy, time_taken = train_rf_model_with_dataframes(train_ds_pd, test_ds_pd, label)
    results_rf.append([num_train, accuracy, time_taken])

    accuracy, time_taken = train_gbdt_model_with_dataframes(train_ds_pd, test_ds_pd, label)
    results_gb.append([num_train, accuracy, time_taken])

    accuracy, time_taken = train_cart_model_with_dataframes(train_ds_pd, test_ds_pd, label)
    results_cm.append([num_train, accuracy, time_taken])

    return results_rf, results_gb, results_cm

# %%
results_rf, results_gb, results_cm = [], [], []
num_train_list = [5000, 10000, 15000, 20000, 25000, 30000, 35000]
for num_train in num_train_list:
    results_rf, results_gb, results_cm = train_and_evaluate_on_data(num_train, results_rf, results_gb, results_cm)
# Out:
# 5000 examples in training, 6188 examples for testing.
# 2021-08-31 17:07:03.721904: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 79/79 [==============================] - 6s 3ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 79
# [INFO kernel.cc:393] Number of examples: 5000
# [INFO kernel.cc:769] Dataset:
# Number of records: 5000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 3191 (63.82%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"fri" 1039 (20.78%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"no" 3982 (79.64%)
# 	8: "education" CATEGORICAL has-dict vocab-size:8 zero-ood-items most-frequent:"university.degree" 1463 (29.26%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 2654 (53.08%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 1305 (26.1%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 4090 (81.8%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 3031 (60.62%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 1648 (32.96%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 4327 (86.54%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0896 min:18 max:87 sd:10.4347
# 	1: "campaign" NUMERICAL mean:2.5958 min:1 max:56 sd:2.97974
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5016 min:-50.8 max:-26.9 sd:4.61245
# 	3: "cons.price.idx" NUMERICAL mean:93.5778 min:92.201 max:94.767 sd:0.581045
# 	7: "duration" NUMERICAL mean:259.995 min:0 max:4199 sd:261.133
# 	9: "emp.var.rate" NUMERICAL mean:0.0758 min:-3.4 max:1.4 sd:1.57676
# 	10: "euribor3m" NUMERICAL mean:3.60992 min:0.634 max:5.045 sd:1.74311
# 	16: "nr.employed" NUMERICAL mean:5166.56 min:4963.6 max:5228.1 sd:72.7443
# 	17: "pdays" NUMERICAL mean:962.264 min:0 max:999 sd:187.418
# 	19: "previous" NUMERICAL mean:0.1712 min:0 max:6 sd:0.493853
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [INFO kernel.cc:797] Training config:
# learner: "RANDOM_FOREST"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO random_forest.cc:303] Training random forest on 5000 example(s) and 20 feature(s).
# [INFO random_forest.cc:578] Training of tree  1/30 (tree index:0) done accuracy:0.8976 logloss:3.69087
# [INFO random_forest.cc:578] Training of tree  11/30 (tree index:9) done accuracy:0.902778 logloss:1.41825
# [INFO random_forest.cc:578] Training of tree  21/30 (tree index:24) done accuracy:0.90218 logloss:0.723709
# [INFO random_forest.cc:578] Training of tree  30/30 (tree index:28) done accuracy:0.9056 logloss:0.538863
# [INFO random_forest.cc:645] Final OOB metrics: accuracy:0.9056 logloss:0.538863
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmp48g3twtx
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 30 root(s), 10774 node(s), and 20 input feature(s).
# [INFO abstract_model.cc:993] Engine "RandomForestOptPred" built
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 1s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9003
# Accuracy: 0.9002909064292908 in 9.803008556365967 secs
# 79/79 [==============================] - 0s 2ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 79
# [INFO kernel.cc:393] Number of examples: 5000
# [INFO kernel.cc:769] Dataset:
# Number of records: 5000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 3191 (63.82%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"fri" 1039 (20.78%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"no" 3982 (79.64%)
# 	8: "education" CATEGORICAL has-dict vocab-size:8 zero-ood-items most-frequent:"university.degree" 1463 (29.26%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 2654 (53.08%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 1305 (26.1%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 4090 (81.8%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 3031 (60.62%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 1648 (32.96%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 4327 (86.54%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0896 min:18 max:87 sd:10.4347
# 	1: "campaign" NUMERICAL mean:2.5958 min:1 max:56 sd:2.97974
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5016 min:-50.8 max:-26.9 sd:4.61245
# 	3: "cons.price.idx" NUMERICAL mean:93.5778 min:92.201 max:94.767 sd:0.581045
# 	7: "duration" NUMERICAL mean:259.995 min:0 max:4199 sd:261.133
# 	9: "emp.var.rate" NUMERICAL mean:0.0758 min:-3.4 max:1.4 sd:1.57676
# 	10: "euribor3m" NUMERICAL mean:3.60992 min:0.634 max:5.045 sd:1.74311
# 	16: "nr.employed" NUMERICAL mean:5166.56 min:4963.6 max:5228.1 sd:72.7443
# 	17: "pdays" NUMERICAL mean:962.264 min:0 max:999 sd:187.418
# 	19: "previous" NUMERICAL mean:0.1712 min:0 max:6 sd:0.493853
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [WARNING gradient_boosted_trees.cc:1692] Subsample hyperparameter given but sampling method does not match.
# [WARNING gradient_boosted_trees.cc:1705] GOSS alpha hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1714] GOSS beta hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1726] SelGB ratio hyperparameter given but SelGB is disabled.
# [INFO kernel.cc:797] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   shrinkage: 0.1
#   validation_set_ratio: 0.1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   apply_link_function: true
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO gradient_boosted_trees.cc:503] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# [INFO gradient_boosted_trees.cc:1079] Training gradient boosted tree on 5000 example(s) and 20 feature(s).
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:1 train-loss:0.607425 train-accuracy:0.890514 valid-loss:0.631548 valid-accuracy:0.891393
# [INFO gradient_boosted_trees.cc:1495] 	num-trees:2 train-loss:0.553935 train-accuracy:0.890514 valid-loss:0.595694 valid-accuracy:0.891393
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:30 train-loss:0.265940 train-accuracy:0.954787 valid-loss:0.462772 valid-accuracy:0.883197
# [INFO gradient_boosted_trees.cc:336] Truncates the model to 29 tree(s) i.e. 29  iteration(s).
# [INFO gradient_boosted_trees.cc:370] Final model num-trees:29 valid-loss:0.461426 valid-accuracy:0.879098
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmp8eaow0r8
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.9034
# Accuracy: 0.9033613204956055 in 1.5930707454681396 secs
# 79/79 [==============================] - 0s 3ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 79
# [INFO kernel.cc:393] Number of examples: 5000
# [INFO kernel.cc:769] Dataset:
# Number of records: 5000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 3191 (63.82%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"fri" 1039 (20.78%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"no" 3982 (79.64%)
# 	8: "education" CATEGORICAL has-dict vocab-size:8 zero-ood-items most-frequent:"university.degree" 1463 (29.26%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 2654 (53.08%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 1305 (26.1%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 4090 (81.8%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 3031 (60.62%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 1648 (32.96%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 4327 (86.54%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0896 min:18 max:87 sd:10.4347
# 	1: "campaign" NUMERICAL mean:2.5958 min:1 max:56 sd:2.97974
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5016 min:-50.8 max:-26.9 sd:4.61245
# 	3: "cons.price.idx" NUMERICAL mean:93.5778 min:92.201 max:94.767 sd:0.581045
# 	7: "duration" NUMERICAL mean:259.995 min:0 max:4199 sd:261.133
# 	9: "emp.var.rate" NUMERICAL mean:0.0758 min:-3.4 max:1.4 sd:1.57676
# 	10: "euribor3m" NUMERICAL mean:3.60992 min:0.634 max:5.045 sd:1.74311
# 	16: "nr.employed" NUMERICAL mean:5166.56 min:4963.6 max:5228.1 sd:72.7443
# 	17: "pdays" NUMERICAL mean:962.264 min:0 max:999 sd:187.418
# 	19: "previous" NUMERICAL mean:0.1712 min:0 max:6 sd:0.493853
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [INFO kernel.cc:797] Training config:
# learner: "CART"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.cart.proto.cart_config] {
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   validation_ratio: 0.1
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO cart.cc:172] Training CART on 5000 example(s) and 20 feature(s).
# [INFO cart.cc:373] 371 nodes before pruning. 57 nodes after pruning.
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmpafvs8trv
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 1 root(s), 57 node(s), and 11 input feature(s).
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.8974
# Accuracy: 0.8973820209503174 in 1.2769403457641602 secs
# 10000 examples in training, 6188 examples for testing.
# 157/157 [==============================] - 1s 3ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 157
# [INFO kernel.cc:393] Number of examples: 10000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column education (7 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 10000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 6363 (63.63%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"mon" 2125 (21.25%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.01%) most-frequent:"no" 7961 (79.61%)
# 	8: "education" CATEGORICAL has-dict vocab-size:8 num-oods:1 (0.01%) most-frequent:"university.degree" 2934 (29.34%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 5259 (52.59%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 2584 (25.84%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 8241 (82.41%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 6055 (60.55%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 3336 (33.36%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 8651 (86.51%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0007 min:18 max:98 sd:10.3038
# 	1: "campaign" NUMERICAL mean:2.6012 min:1 max:56 sd:2.8794
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5532 min:-50.8 max:-26.9 sd:4.59118
# 	3: "cons.price.idx" NUMERICAL mean:93.5785 min:92.201 max:94.767 sd:0.576925
# 	7: "duration" NUMERICAL mean:260.368 min:0 max:4199 sd:263.604
# 	9: "emp.var.rate" NUMERICAL mean:0.08492 min:-3.4 max:1.4 sd:1.56574
# 	10: "euribor3m" NUMERICAL mean:3.6199 min:0.634 max:5.045 sd:1.7346
# 	16: "nr.employed" NUMERICAL mean:5167.13 min:4963.6 max:5228.1 sd:72.2819
# 	17: "pdays" NUMERICAL mean:962.456 min:0 max:999 sd:186.963
# 	19: "previous" NUMERICAL mean:0.1728 min:0 max:6 sd:0.50034
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [INFO kernel.cc:797] Training config:
# learner: "RANDOM_FOREST"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO random_forest.cc:303] Training random forest on 10000 example(s) and 20 feature(s).
# [INFO random_forest.cc:578] Training of tree  1/30 (tree index:1) done accuracy:0.901907 logloss:3.53562
# [INFO random_forest.cc:578] Training of tree  11/30 (tree index:8) done accuracy:0.907754 logloss:1.26949
# [INFO random_forest.cc:578] Training of tree  21/30 (tree index:21) done accuracy:0.9104 logloss:0.64879
# [INFO random_forest.cc:578] Training of tree  30/30 (tree index:29) done accuracy:0.9132 logloss:0.46959
# [INFO random_forest.cc:645] Final OOB metrics: accuracy:0.9132 logloss:0.46959
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmppimdfkwq
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 30 root(s), 19622 node(s), and 20 input feature(s).
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9092
# Accuracy: 0.9091790318489075 in 2.274444341659546 secs
# 157/157 [==============================] - 1s 4ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 157
# [INFO kernel.cc:393] Number of examples: 10000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column education (7 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 10000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 6363 (63.63%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"mon" 2125 (21.25%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.01%) most-frequent:"no" 7961 (79.61%)
# 	8: "education" CATEGORICAL has-dict vocab-size:8 num-oods:1 (0.01%) most-frequent:"university.degree" 2934 (29.34%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 5259 (52.59%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 2584 (25.84%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 8241 (82.41%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 6055 (60.55%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 3336 (33.36%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 8651 (86.51%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0007 min:18 max:98 sd:10.3038
# 	1: "campaign" NUMERICAL mean:2.6012 min:1 max:56 sd:2.8794
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5532 min:-50.8 max:-26.9 sd:4.59118
# 	3: "cons.price.idx" NUMERICAL mean:93.5785 min:92.201 max:94.767 sd:0.576925
# 	7: "duration" NUMERICAL mean:260.368 min:0 max:4199 sd:263.604
# 	9: "emp.var.rate" NUMERICAL mean:0.08492 min:-3.4 max:1.4 sd:1.56574
# 	10: "euribor3m" NUMERICAL mean:3.6199 min:0.634 max:5.045 sd:1.7346
# 	16: "nr.employed" NUMERICAL mean:5167.13 min:4963.6 max:5228.1 sd:72.2819
# 	17: "pdays" NUMERICAL mean:962.456 min:0 max:999 sd:186.963
# 	19: "previous" NUMERICAL mean:0.1728 min:0 max:6 sd:0.50034
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [WARNING gradient_boosted_trees.cc:1692] Subsample hyperparameter given but sampling method does not match.
# [WARNING gradient_boosted_trees.cc:1705] GOSS alpha hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1714] GOSS beta hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1726] SelGB ratio hyperparameter given but SelGB is disabled.
# [INFO kernel.cc:797] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   shrinkage: 0.1
#   validation_set_ratio: 0.1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   apply_link_function: true
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO gradient_boosted_trees.cc:503] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# [INFO gradient_boosted_trees.cc:1079] Training gradient boosted tree on 10000 example(s) and 20 feature(s).
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:1 train-loss:0.597463 train-accuracy:0.893320 valid-loss:0.627944 valid-accuracy:0.889003
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:30 train-loss:0.294808 train-accuracy:0.941730 valid-loss:0.392600 valid-accuracy:0.909558
# [INFO gradient_boosted_trees.cc:336] Truncates the model to 30 tree(s) i.e. 30  iteration(s).
# [INFO gradient_boosted_trees.cc:370] Final model num-trees:30 valid-loss:0.392600 valid-accuracy:0.909558
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmpsqnxh_8u
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO abstract_model.cc:993] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO kernel.cc:848] Use fast generic engine
# WARNING:tensorflow:5 out of the last 5 calls to <function CoreModel.make_predict_function.<locals>.predict_function_trained at 0x7fd502034290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function CoreModel.make_predict_function.<locals>.predict_function_trained at 0x7fd502034290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9084
# Accuracy: 0.9083710312843323 in 2.3366105556488037 secs
# 157/157 [==============================] - 1s 2ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 157
# [INFO kernel.cc:393] Number of examples: 10000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column education (7 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 10000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 6363 (63.63%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"mon" 2125 (21.25%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.01%) most-frequent:"no" 7961 (79.61%)
# 	8: "education" CATEGORICAL has-dict vocab-size:8 num-oods:1 (0.01%) most-frequent:"university.degree" 2934 (29.34%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 5259 (52.59%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 2584 (25.84%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 8241 (82.41%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 6055 (60.55%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 3336 (33.36%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 8651 (86.51%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0007 min:18 max:98 sd:10.3038
# 	1: "campaign" NUMERICAL mean:2.6012 min:1 max:56 sd:2.8794
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5532 min:-50.8 max:-26.9 sd:4.59118
# 	3: "cons.price.idx" NUMERICAL mean:93.5785 min:92.201 max:94.767 sd:0.576925
# 	7: "duration" NUMERICAL mean:260.368 min:0 max:4199 sd:263.604
# 	9: "emp.var.rate" NUMERICAL mean:0.08492 min:-3.4 max:1.4 sd:1.56574
# 	10: "euribor3m" NUMERICAL mean:3.6199 min:0.634 max:5.045 sd:1.7346
# 	16: "nr.employed" NUMERICAL mean:5167.13 min:4963.6 max:5228.1 sd:72.2819
# 	17: "pdays" NUMERICAL mean:962.456 min:0 max:999 sd:186.963
# 	19: "previous" NUMERICAL mean:0.1728 min:0 max:6 sd:0.50034
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [INFO kernel.cc:797] Training config:
# learner: "CART"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.cart.proto.cart_config] {
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   validation_ratio: 0.1
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO cart.cc:172] Training CART on 10000 example(s) and 20 feature(s).
# [INFO cart.cc:373] 697 nodes before pruning. 73 nodes after pruning.
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmp2f0haxnr
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 1 root(s), 73 node(s), and 12 input feature(s).
# [INFO kernel.cc:848] Use fast generic engine
# WARNING:tensorflow:6 out of the last 6 calls to <function CoreModel.make_predict_function.<locals>.predict_function_trained at 0x7fd502042290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function CoreModel.make_predict_function.<locals>.predict_function_trained at 0x7fd502042290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 97/97 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.9026
# Accuracy: 0.9025533199310303 in 1.592790126800537 secs
# 15000 examples in training, 6188 examples for testing.
# 235/235 [==============================] - 1s 3ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 235
# [INFO kernel.cc:393] Number of examples: 15000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 15000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 9537 (63.58%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"mon" 3190 (21.2667%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.00666667%) most-frequent:"no" 11898 (79.32%)
# 	8: "education" CATEGORICAL has-dict vocab-size:9 zero-ood-items most-frequent:"university.degree" 4445 (29.6333%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 7881 (52.54%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 3819 (25.46%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 12395 (82.6333%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 9055 (60.3667%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 4957 (33.0467%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 12944 (86.2933%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:39.9742 min:17 max:98 sd:10.3284
# 	1: "campaign" NUMERICAL mean:2.5822 min:1 max:56 sd:2.80759
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5081 min:-50.8 max:-26.9 sd:4.6077
# 	3: "cons.price.idx" NUMERICAL mean:93.5798 min:92.201 max:94.767 sd:0.577302
# 	7: "duration" NUMERICAL mean:260.432 min:0 max:4918 sd:264.041
# 	9: "emp.var.rate" NUMERICAL mean:0.0937667 min:-3.4 max:1.4 sd:1.56559
# 	10: "euribor3m" NUMERICAL mean:3.63176 min:0.634 max:5.045 sd:1.73098
# 	16: "nr.employed" NUMERICAL mean:5167.43 min:4963.6 max:5228.1 sd:72.3901
# 	17: "pdays" NUMERICAL mean:960.8 min:0 max:999 sd:190.988
# 	19: "previous" NUMERICAL mean:0.1756 min:0 max:6 sd:0.50289
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [INFO kernel.cc:797] Training config:
# learner: "RANDOM_FOREST"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO random_forest.cc:303] Training random forest on 15000 example(s) and 20 feature(s).
# [INFO random_forest.cc:578] Training of tree  1/30 (tree index:1) done accuracy:0.888281 logloss:4.02675
# [INFO random_forest.cc:578] Training of tree  11/30 (tree index:8) done accuracy:0.904746 logloss:1.30466
# [INFO random_forest.cc:578] Training of tree  21/30 (tree index:20) done accuracy:0.907333 logloss:0.680989
# [INFO random_forest.cc:578] Training of tree  30/30 (tree index:27) done accuracy:0.910933 logloss:0.521081
# [INFO random_forest.cc:645] Final OOB metrics: accuracy:0.910933 logloss:0.521081
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmpuuuhanna
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 30 root(s), 28436 node(s), and 20 input feature(s).
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9074
# Accuracy: 0.907401442527771 in 2.43501615524292 secs
# 235/235 [==============================] - 1s 2ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 235
# [INFO kernel.cc:393] Number of examples: 15000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 15000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 9537 (63.58%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"mon" 3190 (21.2667%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.00666667%) most-frequent:"no" 11898 (79.32%)
# 	8: "education" CATEGORICAL has-dict vocab-size:9 zero-ood-items most-frequent:"university.degree" 4445 (29.6333%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 7881 (52.54%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 3819 (25.46%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 12395 (82.6333%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 9055 (60.3667%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 4957 (33.0467%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 12944 (86.2933%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:39.9742 min:17 max:98 sd:10.3284
# 	1: "campaign" NUMERICAL mean:2.5822 min:1 max:56 sd:2.80759
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5081 min:-50.8 max:-26.9 sd:4.6077
# 	3: "cons.price.idx" NUMERICAL mean:93.5798 min:92.201 max:94.767 sd:0.577302
# 	7: "duration" NUMERICAL mean:260.432 min:0 max:4918 sd:264.041
# 	9: "emp.var.rate" NUMERICAL mean:0.0937667 min:-3.4 max:1.4 sd:1.56559
# 	10: "euribor3m" NUMERICAL mean:3.63176 min:0.634 max:5.045 sd:1.73098
# 	16: "nr.employed" NUMERICAL mean:5167.43 min:4963.6 max:5228.1 sd:72.3901
# 	17: "pdays" NUMERICAL mean:960.8 min:0 max:999 sd:190.988
# 	19: "previous" NUMERICAL mean:0.1756 min:0 max:6 sd:0.50289
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [WARNING gradient_boosted_trees.cc:1692] Subsample hyperparameter given but sampling method does not match.
# [WARNING gradient_boosted_trees.cc:1705] GOSS alpha hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1714] GOSS beta hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1726] SelGB ratio hyperparameter given but SelGB is disabled.
# [INFO kernel.cc:797] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   shrinkage: 0.1
#   validation_set_ratio: 0.1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   apply_link_function: true
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO gradient_boosted_trees.cc:503] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# [INFO gradient_boosted_trees.cc:1079] Training gradient boosted tree on 15000 example(s) and 20 feature(s).
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:1 train-loss:0.617971 train-accuracy:0.889884 valid-loss:0.628840 valid-accuracy:0.888366
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:30 train-loss:0.314573 train-accuracy:0.936950 valid-loss:0.387262 valid-accuracy:0.906523
# [INFO gradient_boosted_trees.cc:336] Truncates the model to 29 tree(s) i.e. 29  iteration(s).
# [INFO gradient_boosted_trees.cc:370] Final model num-trees:29 valid-loss:0.387038 valid-accuracy:0.907196
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmpyiis2mmr
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.9119
# Accuracy: 0.9119263291358948 in 2.3759522438049316 secs
# 235/235 [==============================] - 1s 3ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 235
# [INFO kernel.cc:393] Number of examples: 15000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 15000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 9537 (63.58%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"mon" 3190 (21.2667%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.00666667%) most-frequent:"no" 11898 (79.32%)
# 	8: "education" CATEGORICAL has-dict vocab-size:9 zero-ood-items most-frequent:"university.degree" 4445 (29.6333%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 7881 (52.54%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 3819 (25.46%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 12395 (82.6333%)
# ...
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 547
# [INFO kernel.cc:393] Number of examples: 35000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 35000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 22224 (63.4971%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"thu" 7302 (20.8629%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.00285714%) most-frequent:"no" 27687 (79.1057%)
# 	8: "education" CATEGORICAL has-dict vocab-size:9 zero-ood-items most-frequent:"university.degree" 10346 (29.56%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 18366 (52.4743%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 8869 (25.34%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 28835 (82.3857%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 21195 (60.5571%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 11663 (33.3229%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 30222 (86.3486%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0206 min:17 max:98 sd:10.4007
# 	1: "campaign" NUMERICAL mean:2.57337 min:1 max:56 sd:2.80288
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5019 min:-50.8 max:-26.9 sd:4.63316
# 	3: "cons.price.idx" NUMERICAL mean:93.5761 min:92.201 max:94.767 sd:0.578385
# 	7: "duration" NUMERICAL mean:258.328 min:0 max:4918 sd:258.725
# 	9: "emp.var.rate" NUMERICAL mean:0.0843229 min:-3.4 max:1.4 sd:1.56996
# 	10: "euribor3m" NUMERICAL mean:3.62254 min:0.634 max:5.045 sd:1.73426
# 	16: "nr.employed" NUMERICAL mean:5167.09 min:4963.6 max:5228.1 sd:72.2667
# 	17: "pdays" NUMERICAL mean:961.832 min:0 max:999 sd:188.489
# 	19: "previous" NUMERICAL mean:0.173914 min:0 max:7 sd:0.499096
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [INFO kernel.cc:797] Training config:
# learner: "RANDOM_FOREST"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO random_forest.cc:303] Training random forest on 35000 example(s) and 20 feature(s).
# [INFO random_forest.cc:578] Training of tree  1/30 (tree index:0) done accuracy:0.897107 logloss:3.70864
# [INFO random_forest.cc:578] Training of tree  11/30 (tree index:9) done accuracy:0.905833 logloss:1.30974
# [INFO random_forest.cc:578] Training of tree  21/30 (tree index:20) done accuracy:0.910707 logloss:0.67088
# [INFO random_forest.cc:578] Training of tree  30/30 (tree index:29) done accuracy:0.911314 logloss:0.493199
# [INFO random_forest.cc:645] Final OOB metrics: accuracy:0.911314 logloss:0.493199
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmpiy7zcn4s
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 30 root(s), 57616 node(s), and 20 input feature(s).
# [INFO abstract_model.cc:993] Engine "RandomForestOptPred" built
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.9110
# Accuracy: 0.9109566807746887 in 4.761486768722534 secs
# 547/547 [==============================] - 2s 3ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 547
# [INFO kernel.cc:393] Number of examples: 35000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 35000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 22224 (63.4971%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"thu" 7302 (20.8629%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.00285714%) most-frequent:"no" 27687 (79.1057%)
# 	8: "education" CATEGORICAL has-dict vocab-size:9 zero-ood-items most-frequent:"university.degree" 10346 (29.56%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 18366 (52.4743%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 8869 (25.34%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 28835 (82.3857%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 21195 (60.5571%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 11663 (33.3229%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 30222 (86.3486%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0206 min:17 max:98 sd:10.4007
# 	1: "campaign" NUMERICAL mean:2.57337 min:1 max:56 sd:2.80288
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5019 min:-50.8 max:-26.9 sd:4.63316
# 	3: "cons.price.idx" NUMERICAL mean:93.5761 min:92.201 max:94.767 sd:0.578385
# 	7: "duration" NUMERICAL mean:258.328 min:0 max:4918 sd:258.725
# 	9: "emp.var.rate" NUMERICAL mean:0.0843229 min:-3.4 max:1.4 sd:1.56996
# 	10: "euribor3m" NUMERICAL mean:3.62254 min:0.634 max:5.045 sd:1.73426
# 	16: "nr.employed" NUMERICAL mean:5167.09 min:4963.6 max:5228.1 sd:72.2667
# 	17: "pdays" NUMERICAL mean:961.832 min:0 max:999 sd:188.489
# 	19: "previous" NUMERICAL mean:0.173914 min:0 max:7 sd:0.499096
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [WARNING gradient_boosted_trees.cc:1692] Subsample hyperparameter given but sampling method does not match.
# [WARNING gradient_boosted_trees.cc:1705] GOSS alpha hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1714] GOSS beta hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1726] SelGB ratio hyperparameter given but SelGB is disabled.
# [INFO kernel.cc:797] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 30
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   shrinkage: 0.1
#   validation_set_ratio: 0.1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   apply_link_function: true
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO gradient_boosted_trees.cc:503] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# [INFO gradient_boosted_trees.cc:1079] Training gradient boosted tree on 35000 example(s) and 20 feature(s).
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:1 train-loss:0.625893 train-accuracy:0.887856 valid-loss:0.623214 valid-accuracy:0.889592
# [INFO gradient_boosted_trees.cc:1493] 	num-trees:30 train-loss:0.341730 train-accuracy:0.925766 valid-loss:0.365019 valid-accuracy:0.914031
# [INFO gradient_boosted_trees.cc:336] Truncates the model to 30 tree(s) i.e. 30  iteration(s).
# [INFO gradient_boosted_trees.cc:370] Final model num-trees:30 valid-loss:0.365019 valid-accuracy:0.914031
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmpovemzl0o
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9176
# Accuracy: 0.9175823926925659 in 3.681349039077759 secs
# 547/547 [==============================] - 2s 3ms/step
# [INFO kernel.cc:746] Start Yggdrasil model training
# [INFO kernel.cc:747] Collect training examples
# [INFO kernel.cc:392] Number of batches: 547
# [INFO kernel.cc:393] Number of examples: 35000
# [INFO data_spec_inference.cc:289] 1 item(s) have been pruned (i.e. they are considered out of dictionary) for the column default (2 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:769] Dataset:
# Number of records: 35000
# Number of columns: 21
#
# Number of columns by type:
# 	CATEGORICAL: 11 (52.381%)
# 	NUMERICAL: 10 (47.619%)
#
# Columns:
#
# CATEGORICAL: 11 (52.381%)
# 	4: "contact" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"cellular" 22224 (63.4971%)
# 	5: "day_of_week" CATEGORICAL has-dict vocab-size:6 zero-ood-items most-frequent:"thu" 7302 (20.8629%)
# 	6: "default" CATEGORICAL has-dict vocab-size:3 num-oods:1 (0.00285714%) most-frequent:"no" 27687 (79.1057%)
# 	8: "education" CATEGORICAL has-dict vocab-size:9 zero-ood-items most-frequent:"university.degree" 10346 (29.56%)
# 	11: "housing" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"yes" 18366 (52.4743%)
# 	12: "job" CATEGORICAL has-dict vocab-size:13 zero-ood-items most-frequent:"admin." 8869 (25.34%)
# 	13: "loan" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"no" 28835 (82.3857%)
# 	14: "marital" CATEGORICAL has-dict vocab-size:5 zero-ood-items most-frequent:"married" 21195 (60.5571%)
# 	15: "month" CATEGORICAL has-dict vocab-size:11 zero-ood-items most-frequent:"may" 11663 (33.3229%)
# 	18: "poutcome" CATEGORICAL has-dict vocab-size:4 zero-ood-items most-frequent:"nonexistent" 30222 (86.3486%)
# 	20: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 10 (47.619%)
# 	0: "age" NUMERICAL mean:40.0206 min:17 max:98 sd:10.4007
# 	1: "campaign" NUMERICAL mean:2.57337 min:1 max:56 sd:2.80288
# 	2: "cons.conf.idx" NUMERICAL mean:-40.5019 min:-50.8 max:-26.9 sd:4.63316
# 	3: "cons.price.idx" NUMERICAL mean:93.5761 min:92.201 max:94.767 sd:0.578385
# 	7: "duration" NUMERICAL mean:258.328 min:0 max:4918 sd:258.725
# 	9: "emp.var.rate" NUMERICAL mean:0.0843229 min:-3.4 max:1.4 sd:1.56996
# 	10: "euribor3m" NUMERICAL mean:3.62254 min:0.634 max:5.045 sd:1.73426
# 	16: "nr.employed" NUMERICAL mean:5167.09 min:4963.6 max:5228.1 sd:72.2667
# 	17: "pdays" NUMERICAL mean:961.832 min:0 max:999 sd:188.489
# 	19: "previous" NUMERICAL mean:0.173914 min:0 max:7 sd:0.499096
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:772] Configure learner
# [INFO kernel.cc:797] Training config:
# learner: "CART"
# features: "age"
# features: "campaign"
# features: "cons\\.conf\\.idx"
# features: "cons\\.price\\.idx"
# features: "contact"
# features: "day_of_week"
# features: "default"
# features: "duration"
# features: "education"
# features: "emp\\.var\\.rate"
# features: "euribor3m"
# features: "housing"
# features: "job"
# features: "loan"
# features: "marital"
# features: "month"
# features: "nr\\.employed"
# features: "pdays"
# features: "poutcome"
# features: "previous"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.cart.proto.cart_config] {
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   validation_ratio: 0.1
# }
#
# [INFO kernel.cc:800] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:837] Train model
# [INFO cart.cc:172] Training CART on 35000 example(s) and 20 feature(s).
# [INFO cart.cc:373] 1971 nodes before pruning. 265 nodes after pruning.
# [INFO kernel.cc:856] Export model in log directory: /tmp/tmp4zqm_qs0
# [INFO kernel.cc:864] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 1 root(s), 265 node(s), and 19 input feature(s).
# [INFO kernel.cc:848] Use fast generic engine
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.9085
# Accuracy: 0.9085326194763184 in 2.861142873764038 secs

# %% [markdown]
# ## Plotting Results

# %%
x  = [res[0] for res in results_rf]
y1 = [res[1] for res in results_rf]
y2 = [res[1] for res in results_gb]
y3 = [res[1] for res in results_cm]
plt.plot(x, y1, label="Random Forests", marker='^')
plt.plot(x, y2, label="Gradient Boosting", marker='o')
plt.plot(x, y3, label="CART", marker='o')
plt.plot()

plt.xlabel("Number of Records")
plt.ylabel("Accuracy")
plt.title("Plot of # of Records vs. Accuracies")
plt.legend()
plt.show()

# %%
x  = [res[0] for res in results_rf]
y1 = [res[2] for res in results_rf]
y2 = [res[2] for res in results_gb]
y3 = [res[1] for res in results_cm]
plt.plot(x, y1, label="Random Forests", marker='^')
plt.plot(x, y2, label="Gradient Boosting", marker='o')
plt.plot(x, y3, label="CART", marker='o')
plt.plot()

plt.xlabel("Number of Records")
plt.ylabel("Time Taken (secs)")
plt.title("Plot of # of Records vs. Time Taken to Train")
plt.legend()
plt.show()

# %%
df_results = pd.DataFrame()
df_results["Number of Records"] = [res[0] for res in results_rf]
df_results["RF"] = [res[1] / res[2] for res in results_gb]
df_results["GB"] = [res[1] / res[2] for res in results_gb]
df_results["CART"] = [res[1] / res[2] for res in results_cm]

df_results.head()
# Out:
#    Number of Records        RF        GB      CART
# 0               5000  0.566772  0.566772  0.702302
# 1              10000  0.388625  0.388625  0.566619
# 2              15000  0.383580  0.383580  0.401089
# 3              20000  0.243089  0.243089  0.488723
# 4              25000  0.315336  0.315336  0.363675

# %%
df_results = pd.DataFrame()
df_results["Number of Records"] = [res[0] for res in results_rf]
df_results["RF"] = [res[1] for res in results_gb]
df_results["GB"] = [res[1] for res in results_gb]
df_results["CART"] = [res[1] for res in results_cm]

df_results.head()
# Out:
#    Number of Records        RF        GB      CART
# 0               5000  0.903361  0.903361  0.897382
# 1              10000  0.908371  0.908371  0.902553
# 2              15000  0.911926  0.911926  0.905947
# 3              20000  0.914835  0.914835  0.908371
# 4              25000  0.914835  0.914835  0.904816

# %%
df_results = pd.DataFrame()
df_results["Number of Records"] = [res[0] for res in results_rf]
df_results["RF"] = [res[2] for res in results_gb]
df_results["GB"] = [res[2] for res in results_gb]
df_results["CART"] = [res[2] for res in results_cm]

df_results.head()
# Out:
#    Number of Records        RF        GB      CART
# 0               5000  1.593871  1.593871  1.277772
# 1              10000  2.337398  2.337398  1.592875
# 2              15000  2.377405  2.377405  2.258719
# 3              20000  3.763381  3.763381  1.858661
# 4              25000  2.901140  2.901140  2.487980
